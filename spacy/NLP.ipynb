# %% [markdown]
# # Processamento de Linguagem Natural (Natural Language Processing)
# O computados tem dificuldade em processar dados não estruturados, printipalmento no que se refere a texto e linguagem, com o surjimento da demanda e foram criando formas de fazer o computador processar textos e com o surgimento do machine learning e as redes neurais artificiais trouxe mais possibilidades
# ## Corpus
# Conjunto de documentos(Textos não estruturado) em linguagem natural
#
# ## Annotations
# Localizar e classificar elementos especificos no texto.
#  * Exemplos:
#     * Anotar sentimentos para treinamento de IA
# * Podendo ser especifica por dominio ex. Medicina;
# * Existem empresas especificas especializadas em anotar
# * Existem ferramentas expecializadas como: Doccano, Brat etc.
# * Alguns tipos podem ser feitas por maquinas
#
# ## Tokenização
# Processo de subdivisão das sentenças em partes: palavras, pontos e símbulos etc.
#
# ## Parts-of-speech (POS) tagging
# Adiciona tags a cada tokem por exemplo sé é verbo, substantivo, adjetivo etc.
#
# ## Lemmatizing (lemma)
# Trazer a palavra na sua flexão, de modo que possam ser analizadas juntas.
#
# ## stemming
# * Corta palavras, buscando ter uma representação raiz unica
# * Diferentes tecnicas
# * Lemmatization é mais sofisticado
# * Amigo, amigos, amiga, amigas => amig
#
# ## Dependency parsing
# Busca encontrar relação entre palvras
#
# ### Ngram
# * N palavras sonsecutivas
# * Bigrams e trigrams
# * 4 ou mais não é utilizado devido a esparsidade
# * pode ser aplicado em letras
#
# ## Modelo
# Um modelo de banco de dados linguistico
# * Analize:
#    * Verbo, substantivo, quais são as flexôes? Quais são as dependencias
# * Especifico para cada idioma
# * Maioria das bibliotecas de NLP tem seus próprios modelos (ou usam modelos de terceiros)
# * Pode criar seu
#
# ### Word Embedding
# É representações computacionais de texto:
#
# * independente de contexto
# * dependente de contexto
#
# ### One-hot encode
# É uma representação matricial de uma fraze em uma matriz formada por zeros e uns
#
# ### TF-IDF
# É feita pela frequencia das palavras utilizadas na frase palavras mais frequentes tendem a se aproximar de 0 e palavras menos frequentes tendem a ter valor mais alto
#
# ## word2vec
# Atravez de um processo de treinamento, produz um vetor demonstrando matematicamente a relação entre palavras existem duas formas principais:
#
# * CBOW: busca prever uma palavra baseadono contxto
# * Skip-gram: busca prever o contexto a partir de uma palavra central

# %%
import spacy

# %%
with open('teste.txt', 'r') as txt:
    text = txt.read()
    txt.close()

# %%
spacy.cli.download('pt_core_news_lg')
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load('pt_core_news_lg')
doc = nlp(text)
display(doc)
# Out:
# Era uma vez na encantadora cidade de Porto Alegre, no sul do Brasil, um jovem chamado João que sonhava em se tornar um renomado cientista. Ele estudava na Universidade Federal do Rio Grande do Sul (UFRGS) e passava seus dias no Laboratório de Pesquisa Avançada, onde trabalhava em projetos inovadores.
#
# João era fascinado por astronomia e tinha um telescópio sofisticado da marca Celestron, um presente de seu avô, que também era um apaixonado pelo céu noturno. No laboratório, ele colaborava com a Dra. Maria, uma astrofísica renomada, e com seu colega de classe, Pedro, um entusiasta da física quântica.
#
# ...

# %%
print('Tokens: ', [token.text for token in doc], end='\n\n')
print('Stop Word: ', [token.text for token in doc if token.is_stop], end='\n\n')
print('Alfanumerico: ', [token.text for token in doc if token.is_alpha], end='\n\n')
print('Maiúsculo: ', [token.text for token in doc if token.is_upper], end='\n\n')
print('Pontuação: ', [token.text for token in doc if token.is_punct], end='\n\n')
print('Número: ', [token.text for token in doc if token.like_num], end='\n\n')
print('Número: ', [token.text for token in doc if token.is_sent_start], end='\n\n')
# Out:
# Tokens:  ['Era', 'uma', 'vez', 'na', 'encantadora', 'cidade', 'de', 'Porto', 'Alegre', ',', 'no', 'sul', 'do', 'Brasil', ',', 'um', 'jovem', 'chamado', 'João', 'que', 'sonhava', 'em', 'se', 'tornar', 'um', 'renomado', 'cientista', '.', 'Ele', 'estudava', 'na', 'Universidade', 'Federal', 'do', 'Rio', 'Grande', 'do', 'Sul', '(', 'UFRGS', ')', 'e', 'passava', 'seus', 'dias', 'no', 'Laboratório', 'de', 'Pesquisa', 'Avançada', ',', 'onde', 'trabalhava', 'em', 'projetos', 'inovadores', '.', '\n \n', 'João', 'era', 'fascinado', 'por', 'astronomia', 'e', 'tinha', 'um', 'telescópio', 'sofisticado', 'da', 'marca', 'Celestron', ',', 'um', 'presente', 'de', 'seu', 'avô', ',', 'que', 'também', 'era', 'um', 'apaixonado', 'pelo', 'céu', 'noturno', '.', 'No', 'laboratório', ',', 'ele', 'colaborava', 'com', 'a', 'Dra', '.', 'Maria', ',', 'uma', 'astrofísica', 'renomada', ',', 'e', 'com', 'seu', 'colega', 'de', 'classe', ',', 'Pedro', ',', 'um', 'entusiasta', 'da', 'física', 'quântica', '.', '\n \n', 
# ...

# %%
print('Tokens: ', [token.text for token in doc], end='\n\n')
print('Formato: ', [token.shape_ for token in doc], end='\n\n')
# Out:
# Tokens:  ['Era', 'uma', 'vez', 'na', 'encantadora', 'cidade', 'de', 'Porto', 'Alegre', ',', 'no', 'sul', 'do', 'Brasil', ',', 'um', 'jovem', 'chamado', 'João', 'que', 'sonhava', 'em', 'se', 'tornar', 'um', 'renomado', 'cientista', '.', 'Ele', 'estudava', 'na', 'Universidade', 'Federal', 'do', 'Rio', 'Grande', 'do', 'Sul', '(', 'UFRGS', ')', 'e', 'passava', 'seus', 'dias', 'no', 'Laboratório', 'de', 'Pesquisa', 'Avançada', ',', 'onde', 'trabalhava', 'em', 'projetos', 'inovadores', '.', '\n \n', 'João', 'era', 'fascinado', 'por', 'astronomia', 'e', 'tinha', 'um', 'telescópio', 'sofisticado', 'da', 'marca', 'Celestron', ',', 'um', 'presente', 'de', 'seu', 'avô', ',', 'que', 'também', 'era', 'um', 'apaixonado', 'pelo', 'céu', 'noturno', '.', 'No', 'laboratório', ',', 'ele', 'colaborava', 'com', 'a', 'Dra', '.', 'Maria', ',', 'uma', 'astrofísica', 'renomada', ',', 'e', 'com', 'seu', 'colega', 'de', 'classe', ',', 'Pedro', ',', 'um', 'entusiasta', 'da', 'física', 'quântica', '.', '\n \n', 
# ...

# %%
for token in doc:
    print(token.text, ' - ', token.pos_, ' - ', token.dep_, ' - ', token.lemma_, ' - ', token.shape_)
# Out:
# Era  -  AUX  -  cop  -  ser  -  Xxx
# uma  -  DET  -  det  -  um  -  xxx
# vez  -  NOUN  -  ROOT  -  vez  -  xxx
# na  -  ADP  -  case  -  em o  -  xx
# encantadora  -  ADJ  -  amod  -  encantadoro  -  xxxx
# cidade  -  NOUN  -  nmod  -  cidade  -  xxxx
# de  -  ADP  -  case  -  de  -  xx
# Porto  -  PROPN  -  nmod  -  Porto  -  Xxxxx
# Alegre  -  PROPN  -  flat:name  -  Alegre  -  Xxxxx
# ,  -  PUNCT  -  punct  -  ,  -  ,
# no  -  ADP  -  case  -  em o  -  xx
# sul  -  NOUN  -  nmod  -  sul  -  xxx
# do  -  ADP  -  case  -  de o  -  xx
# Brasil  -  PROPN  -  nmod  -  Brasil  -  Xxxxx
# ,  -  PUNCT  -  punct  -  ,  -  ,
# um  -  DET  -  det  -  um  -  xx
# jovem  -  NOUN  -  conj  -  jovem  -  xxxx
# chamado  -  VERB  -  amod  -  chamar  -  xxxx
# João  -  PROPN  -  appos  -  João  -  Xxxx
# que  -  PRON  -  nsubj  -  que  -  xxx
# sonhava  -  VERB  -  acl:relcl  -  sonhar  -  xxxx
# em  -  SCONJ  -  mark  -  em  -  xx
# se  -  PRON  -  expl  -  se  -  xx
# ...

# %%
for token in doc:
    print(token.text, ' - ', token.morph)
# Out:
# Era  -  Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin
# uma  -  Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# vez  -  Gender=Fem|Number=Sing
# na  -  Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# encantadora  -  Gender=Fem|Number=Sing
# cidade  -  Gender=Fem|Number=Sing
# de  -
# Porto  -  Gender=Masc|Number=Sing
# Alegre  -  Number=Sing
# ,  -
# no  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# sul  -  Gender=Masc|Number=Sing
# do  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# Brasil  -  Gender=Masc|Number=Sing
# ,  -
# um  -  Definite=Ind|Gender=Masc|Number=Sing|PronType=Art
# jovem  -  Gender=Masc|Number=Sing
# chamado  -  Gender=Masc|Number=Sing|VerbForm=Part
# João  -  Gender=Masc|Number=Sing
# que  -  Gender=Masc|Number=Sing|PronType=Rel
# sonhava  -  Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin
# em  -
# se  -  Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# tornar  -  VerbForm=Inf
# ...

# %%
for token in doc:
    print(token.text, ' - ', token.tag_)
# Out:
# Era  -  AUX
# uma  -  DET
# vez  -  NOUN
# na  -  ADP
# encantadora  -  ADJ
# cidade  -  NOUN
# de  -  ADP
# Porto  -  PROPN
# Alegre  -  PROPN
# ,  -  PUNCT
# no  -  ADP
# sul  -  NOUN
# do  -  ADP
# Brasil  -  PROPN
# ,  -  PUNCT
# um  -  DET
# jovem  -  NOUN
# chamado  -  VERB
# João  -  PROPN
# que  -  PRON
# sonhava  -  VERB
# em  -  SCONJ
# se  -  PRON
# tornar  -  VERB
# um  -  DET
# renomado  -  ADJ
# cientista  -  ADJ
# .  -  PUNCT
# Ele  -  PRON
# estudava  -  VERB
# na  -  ADP
# Universidade  -  PROPN
# Federal  -  PROPN
# do  -  ADP
# Rio  -  PROPN
# Grande  -  PROPN
# do  -  ADP
# Sul  -  PROPN
# (  -  PUNCT
# UFRGS  -  PROPN
# )  -  PUNCT
# e  -  CCONJ
# passava  -  VERB
# seus  -  DET
# dias  -  NOUN
# no  -  ADP
# Laboratório  -  PROPN
# de  -  ADP
# Pesquisa  -  PROPN
# Avançada  -  PROPN
# ,  -  PUNCT
# onde  -  PRON
# trabalhava  -  VERB
# em  -  ADP
# projetos  -  NOUN
# inovadores  -  ADJ
# .  -  PUNCT
#
#
#   -  SPACE
# João  -  PROPN
# era  -  AUX
# ...

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Porto Alegre LOC
# Brasil LOC
# João PER
# Universidade Federal do Rio Grande do Sul LOC
# UFRGS LOC
# Laboratório de Pesquisa Avançada LOC
# João PER
# Celestron PER
# Dra ORG
# Maria PER
# Pedro PER
# Certo PER
# Órion LOC
# João PER
# Dra LOC
# Maria PER
# Titan MISC
# Instituto Nacional de Pesquisas Espaciais LOC
# INPE LOC
# Pedro PER
# João PER
# NASA ORG
# Agência Espacial Europeia ORG
# ESA ORG
# João PER
# Conferência Internacional de Astronomia ORG
# Paris LOC
# FAPERGS LOC
# Fundação de Amparo à Pesquisa do Estado do Rio Grande do Sul LOC
# João PER
# França LOC
# Porto Alegre LOC
# João PER
# Scientific American ORG
# Folha de S.Paulo PER
# João PER

# %%
# é uma boa pratica remover stop word
for token in doc:
    if token.is_stop:
        print(token.text)
# Out:
# Era
# uma
# vez
# na
# de
# no
# do
# um
# que
# em
# se
# um
# Ele
# na
# do
# Grande
# do
# e
# seus
# no
# de
# onde
# em
# era
# por
# e
# um
# da
# um
# de
# seu
# que
# também
# era
# um
# pelo
# No
# ele
# com
# a
# uma
# e
# com
# seu
# de
# um
# da
# enquanto
# a
# de
# uma
# nos
# Ele
# sua
# com
# a
# que
# uma
# mais
# o
# no
# de
# Com
# a
# de
# os
# e
# que
# um
# novo
# uma
# A
# a
# da
# e
# da
# que
# e
# sua
# para
# seus
# na
# de
# a
# ser
# em
# Com
# o
# apoio
# da
# de
# à
# do
# Estado
# do
# Grande
# do
# para
# a
# onde
# seu
# foi
# e
# por
# de
# todo
# o
# Ao
# a
# foi
# como
# um
# A
# da
# uma
# em
# sua
# e
# ele
# foi
# por
# de
# a
# e
# o
# de
# Sua
# não
# só
# o
# da
# mas
# também
# muitos
# a
# seus
# e
# sempre
# os
# do
# Ele
# que
# sua
# estava
# apenas
# e
# que
# com
# e
# ainda
# mais
# no

# %%
#como definir um novo stop word
#nlp.Defaults.stop_words.add('eita')
#nlp.vocab['eita'].is_stop(True)

# %%
print(type(nlp.Defaults.stop_words))
# Out:
# <class 'set'>

# %%
token_lista = []
for token in doc:
    token_lista.append(token.text)

stop_lista = []
for word in nlp.Defaults.stop_words:
    stop_lista.append(word)

sem_stop = [word for word in token_lista if word not in stop_lista]
print(sem_stop)
# Out:
# ['Era', 'encantadora', 'cidade', 'Porto', 'Alegre', ',', 'sul', 'Brasil', ',', 'jovem', 'chamado', 'João', 'sonhava', 'tornar', 'renomado', 'cientista', '.', 'Ele', 'estudava', 'Universidade', 'Federal', 'Rio', 'Grande', 'Sul', '(', 'UFRGS', ')', 'passava', 'dias', 'Laboratório', 'Pesquisa', 'Avançada', ',', 'trabalhava', 'projetos', 'inovadores', '.', '\n \n', 'João', 'fascinado', 'astronomia', 'tinha', 'telescópio', 'sofisticado', 'marca', 'Celestron', ',', 'presente', 'avô', ',', 'apaixonado', 'céu', 'noturno', '.', 'No', 'laboratório', ',', 'colaborava', 'Dra', '.', 'Maria', ',', 'astrofísica', 'renomada', ',', 'colega', 'classe', ',', 'Pedro', ',', 'entusiasta', 'física', 'quântica', '.', '\n \n', 'Certo', 'dia', ',', 'observava', 'constelação', 'Órion', ',', 'João', 'notou', 'anomalia', 'dados', 'coletados', '.', 'Ele', 'imediatamente', 'compartilhou', 'descoberta', 'Dra', '.', 'Maria', ',', 'sugeriu', 'análise', 'aprofundada', 'utilizando', 'supercomputador', 'Titan', ',', 'lo
# ...

# %%
sem_stop_new = [token.text for token in doc if token.text not in nlp.Defaults.stop_words]
print(sem_stop_new)
# Out:
# ['Era', 'encantadora', 'cidade', 'Porto', 'Alegre', ',', 'sul', 'Brasil', ',', 'jovem', 'chamado', 'João', 'sonhava', 'tornar', 'renomado', 'cientista', '.', 'Ele', 'estudava', 'Universidade', 'Federal', 'Rio', 'Grande', 'Sul', '(', 'UFRGS', ')', 'passava', 'dias', 'Laboratório', 'Pesquisa', 'Avançada', ',', 'trabalhava', 'projetos', 'inovadores', '.', '\n \n', 'João', 'fascinado', 'astronomia', 'tinha', 'telescópio', 'sofisticado', 'marca', 'Celestron', ',', 'presente', 'avô', ',', 'apaixonado', 'céu', 'noturno', '.', 'No', 'laboratório', ',', 'colaborava', 'Dra', '.', 'Maria', ',', 'astrofísica', 'renomada', ',', 'colega', 'classe', ',', 'Pedro', ',', 'entusiasta', 'física', 'quântica', '.', '\n \n', 'Certo', 'dia', ',', 'observava', 'constelação', 'Órion', ',', 'João', 'notou', 'anomalia', 'dados', 'coletados', '.', 'Ele', 'imediatamente', 'compartilhou', 'descoberta', 'Dra', '.', 'Maria', ',', 'sugeriu', 'análise', 'aprofundada', 'utilizando', 'supercomputador', 'Titan', ',', 'lo
# ...

# %%
print(sem_stop == sem_stop_new)
# Out:
# True

# %%
print('Hash: ', nlp.vocab.strings['dados'])
print('Hash: ', doc.vocab.strings['dados'])
print('String: ', nlp.vocab.strings[6013848609874238634])
# Out:
# Hash:  6013848609874238634
# Hash:  6013848609874238634
# String:  dados

# %%
lex = nlp.vocab["dados"]
print(lex.text, ' - ', lex.orth, ' - ', lex.is_alpha, ' - ', lex.is_lower)
# Out:
# dados  -  6013848609874238634  -  True  -  True

# %%
print(nlp('dados').vector.shape)
# Out:
# (300,)

# %%
#embedings
print(nlp('dados são uma nova forma de ver o mundo').vector)
# Out:
# [ 0.5255733  -1.0520301  -1.0489888   0.22808893 -2.7599888   0.91837215
#  -1.6993556  -0.44524103 -2.209261   -1.2901455   0.9939946  -1.3996754
#   0.7378708  -1.6957022  -1.382649   -1.1241877   2.503239    1.3766589
#  -0.63682556  2.7080245  -0.6679023   0.7990059  -1.3761922   1.6491444
#  -0.6950322   0.69378555 -0.19840002  1.6926199  -0.3071023   0.71506053
#   0.03211441  0.27212894 -1.9055911  -1.5586021  -0.9775556   0.7999823
#  -0.9553054   0.5265729  -0.87427455 -1.2073755  -2.117481    1.2241988
#   1.5149522  -0.79308677 -1.1521667   0.13741441 -1.7882053   0.50415283
#   1.3089666   0.06542712 -0.6260744  -1.5624356  -0.707184   -1.2425367
#  -0.04237115 -0.5879791   1.7004043  -0.24798778  0.11633212 -0.55506223
#   2.0148706   0.01965364  0.92778563  2.3571968  -0.49526003  1.0151839
#   0.57112557  1.3510779  -0.3038622  -0.24523441 -0.42284998 -0.69732666
#   0.71998227  0.2875956   0.10309222 -0.6866155   2.128672    0.9791889
# ...

# %% [markdown]
# # similaridade
# É uma metrica de de semelhança baseado em contexto é necessario o modelo large do
# idioma metrica é o coseno, valor de 0 a 1, utiliza representação vetorial word embeddings
# word2vec pode ser aplicado em tokens, spans e docs melhora de preformance utilizando spans ou
# sentenças menores pode utilizar outra função similaridade ex. (sense2vec), remove stop words, pontuação e pronomes
# # matcher
# busca um padrão e retorna se encontra similar a um regex

# %%
doc1 = nlp('Ele viaja regularmente de avião')
doc2 = nlp('Ele regularmente de avião viaja')
print(doc1.similarity(doc2))
print(doc2.similarity(doc1))
# Out:
# 1.000000045915569
# 1.000000045915569

# %%
doc3 = nlp('devemos dizer comprimento ou cumprimento?')
token1 = doc3[2]
token2 = doc3[4]
print(token1, ' e ', token2, ' tem similaridade de ', token1.similarity(token2))
# Out:
# comprimento  e  cumprimento  tem similaridade de  0.5804340243339539

# %%
doc4 = nlp('Ele quer descrição. Ele quer discrição')
span1 = doc4[0:3]
span2 = doc4[4:7]
print(span1, ' e ', span2, ' tem similaridade de ', span1.similarity(span2))
# Out:
# Ele quer descrição  e  Ele quer discrição  tem similaridade de  0.9688021540641785

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)

pattern = [{'ORTH': '('}, {'SHAPE': 'dd'}, {'ORTH': ')'}, {'ORTH': '-' , 'OP': '?'}, 
           {"IS_DIGIT": True}]
matcher.add('Telefone', [pattern])

doc5 = nlp('Você pode ligar para (51) - 9964656570 ou (11) 12344988')

matches = matcher(doc5)
for match_id, start, end in matches:
    print(doc5[start:end])
# Out:
# (51) - 9964656570
# (11) 12344988

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Era uma vez na encantadora cidade de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Porto Alegre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , no sul do
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brasil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , um jovem chamado
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     João
# ...

# %%
displacy.render(doc, style='dep', jupyter = True,
               options = {'compact': True, 'distance':100, 'color': '#0000FF', 
                          'bg': '#000000', 'font':'Arial'})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="1920224349524d23832e732cf83a50a9-0" class="displacy" width="32950" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #0000FF; background: #000000; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Era</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">uma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %%
text
# Out:
# 'Era uma vez na encantadora cidade de Porto Alegre, no sul do Brasil, um jovem chamado João que sonhava em se tornar um renomado cientista. Ele estudava na Universidade Federal do Rio Grande do Sul (UFRGS) e passava seus dias no Laboratório de Pesquisa Avançada, onde trabalhava em projetos inovadores.\n \nJoão era fascinado por astronomia e tinha um telescópio sofisticado da marca Celestron, um presente de seu avô, que também era um apaixonado pelo céu noturno. No laboratório, ele colaborava com a Dra. Maria, uma astrofísica renomada, e com seu colega de classe, Pedro, um entusiasta da física quântica.\n \nCerto dia, enquanto observava a constelação de Órion, João notou uma anomalia nos dados coletados. Ele imediatamente compartilhou sua descoberta com a Dra. Maria, que sugeriu uma análise mais aprofundada utilizando o supercomputador Titan, localizado no Instituto Nacional de Pesquisas Espaciais (INPE). Com a ajuda de Pedro, João conseguiu interpretar os dados e concluiu que havia e
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer, LancasterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag, pos_tag_sents

import string

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('tagsets')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package tagsets to /home/jovyan/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/jovyan/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
texto = 'Nós somos feitos de poeira de estrelas. Nós somos uma maneira do cosmos se autoconhecer. A imaginação nos leva a mundos que nunca se quer existiram. Mas sem ela não vamos a lugar algum.' 
print(texto)
# Out:
# Nós somos feitos de poeira de estrelas. Nós somos uma maneira do cosmos se autoconhecer. A imaginação nos leva a mundos que nunca se quer existiram. Mas sem ela não vamos a lugar algum.

# %%
sentencas = sent_tokenize(texto, 'portuguese')
print(sentencas)
# Out:
# ['Nós somos feitos de poeira de estrelas.', 'Nós somos uma maneira do cosmos se autoconhecer.', 'A imaginação nos leva a mundos que nunca se quer existiram.', 'Mas sem ela não vamos a lugar algum.']

# %%
palavras = word_tokenize(texto, 'portuguese')
print(palavras)
# Out:
# ['Nós', 'somos', 'feitos', 'de', 'poeira', 'de', 'estrelas', '.', 'Nós', 'somos', 'uma', 'maneira', 'do', 'cosmos', 'se', 'autoconhecer', '.', 'A', 'imaginação', 'nos', 'leva', 'a', 'mundos', 'que', 'nunca', 'se', 'quer', 'existiram', '.', 'Mas', 'sem', 'ela', 'não', 'vamos', 'a', 'lugar', 'algum', '.']

# %%
stop = stopwords.words('portuguese')
print(stop)
# Out:
# ['a', 'à', 'ao', 'aos', 'aquela', 'aquelas', 'aquele', 'aqueles', 'aquilo', 'as', 'às', 'até', 'com', 'como', 'da', 'das', 'de', 'dela', 'delas', 'dele', 'deles', 'depois', 'do', 'dos', 'e', 'é', 'ela', 'elas', 'ele', 'eles', 'em', 'entre', 'era', 'eram', 'éramos', 'essa', 'essas', 'esse', 'esses', 'esta', 'está', 'estamos', 'estão', 'estar', 'estas', 'estava', 'estavam', 'estávamos', 'este', 'esteja', 'estejam', 'estejamos', 'estes', 'esteve', 'estive', 'estivemos', 'estiver', 'estivera', 'estiveram', 'estivéramos', 'estiverem', 'estivermos', 'estivesse', 'estivessem', 'estivéssemos', 'estou', 'eu', 'foi', 'fomos', 'for', 'fora', 'foram', 'fôramos', 'forem', 'formos', 'fosse', 'fossem', 'fôssemos', 'fui', 'há', 'haja', 'hajam', 'hajamos', 'hão', 'havemos', 'haver', 'hei', 'houve', 'houvemos', 'houver', 'houvera', 'houverá', 'houveram', 'houvéramos', 'houverão', 'houverei', 'houverem', 'houveremos', 'houveria', 'houveriam', 'houveríamos', 'houvermos', 'houvesse', 'houvessem', 'houvés
# ...

# %%
tokens = [token for token in palavras if token not in stop if token not in string.punctuation]
print(tokens)
# Out:
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'quer', 'existiram', 'Mas', 'vamos', 'lugar', 'algum']

# %%
doc = nlp(texto)
sem_stop_new = [token.text for token in doc if token.text not in nlp.Defaults.stop_words if not token.is_punct]
print(sem_stop_new)
# Out:
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'leva', 'mundos', 'existiram', 'Mas', 'vamos', 'algum']

# %%
frequencia = nltk.FreqDist(tokens)
frequencia.most_common(5)
# Out:
# [('Nós', 2), ('feitos', 1), ('poeira', 1), ('estrelas', 1), ('maneira', 1)]

# %%
stemmer = PorterStemmer()
stem1 = [stemmer.stem(token) for token in tokens]
print(stem1)
# Out:
# ['nó', 'feito', 'poeira', 'estrela', 'nó', 'maneira', 'cosmo', 'autoconhec', 'a', 'imaginação', 'leva', 'mundo', 'nunca', 'quer', 'existiram', 'ma', 'vamo', 'lugar', 'algum']

# %%
stemmer2 = SnowballStemmer('portuguese')
stem2 = [stemmer2.stem(token) for token in tokens]
print(stem2)
# Out:
# ['nós', 'feit', 'poeir', 'estrel', 'nós', 'maneir', 'cosm', 'autoconhec', 'a', 'imagin', 'lev', 'mund', 'nunc', 'quer', 'exist', 'mas', 'vam', 'lug', 'algum']

# %%
stemmer3 = LancasterStemmer()
stem3 = [stemmer3.stem(token) for token in tokens]
print(stem3)
# Out:
# ['nós', 'feito', 'poeir', 'estrela', 'nós', 'maneir', 'cosmo', 'autoconhec', 'a', 'imaginação', 'lev', 'mundo', 'nunc', 'quer', 'existiram', 'mas', 'vamo', 'lug', 'alg']

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
pos = nltk.pos_tag(tokens, lang='port')
print(pos)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 pos = nltk.pos_tag(tokens, lang='port')
#       2 print(pos)
#
# File /opt/conda/lib/python3.11/site-packages/nltk/tag/__init__.py:166, in pos_tag(tokens, tagset, lang)
#     141 """
#     142 Use NLTK's currently recommended part of speech tagger to
#     143 tag the given list of tokens.
#    (...)
#     163 :rtype: list(tuple(str, str))
#     164 """
#     165 tagger = _get_tagger(lang)
# --> 166 return _pos_tag(tokens, tagset, tagger, lang)
#
# File /opt/conda/lib/python3.11/site-packages/nltk/tag/__init__.py:114, in _pos_tag(tokens, tagset, tagger, lang)
#     111 def _pos_tag(tokens, tagset=None, tagger=None, lang=None):
#     112     # Currently only supports English and Russian.
#     113     if lang not in ["eng", "rus"]:
# --> 114         raise NotImplementedError(
# ...

# %%
ntokens = []
for token in sentencas:
    ntokens.append(word_tokenize(token))

# %%
print(ntokens)
# Out:
# [['Nós', 'somos', 'feitos', 'de', 'poeira', 'de', 'estrelas', '.'], ['Nós', 'somos', 'uma', 'maneira', 'do', 'cosmos', 'se', 'autoconhecer', '.'], ['A', 'imaginação', 'nos', 'leva', 'a', 'mundos', 'que', 'nunca', 'se', 'quer', 'existiram', '.'], ['Mas', 'sem', 'ela', 'não', 'vamos', 'a', 'lugar', 'algum', '.']]

# %%
lemmatizer = WordNetLemmatizer()
resultado = [lemmatizer.lemmatize(token) for token in tokens]
print(resultado)
# Out:
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'lev', 'mundos', 'nunca', 'quer', 'existiram', 'Mas', 'vamos', 'lugar', 'algum']

# %%
texto1 = 'Barack Obama foi um presidente dos EUA'
tok = word_tokenize(texto1)
tags = pos_tag(tok)
en = nltk.ne_chunk(tags)
print(tags)
# Out:
# [('Barack', 'NNP'), ('Obama', 'NNP'), ('foi', 'NN'), ('um', 'JJ'), ('presidente', 'NN'), ('dos', 'NN'), ('EUA', 'NNP')]
